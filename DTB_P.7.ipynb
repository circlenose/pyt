# %% [markdown]
# # 매트플롯립을 이용한 데이터 시각화

# %% [markdown]
# ### 7.1 데이터 시각화

# %% [markdown]
# 7.1.1 데이터 시각화
# 숫자만으로는 알 수 없는 사실 발견 가능 -> 데이터에 대한 보다 깊은 이해

# %% [markdown]
# 7.1.2 라이브러리 임포트

# %%
# 라이브러리 임포트
import numpy as np
import numpy.random as random
import scipy as sp
import pandas as pd
from pandas import Series, DataFrame

# 시각화 라이브러리
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
sns.set()
# %matplotlib inline

# 소수점 세 번째 자리까지 표시
# %precision 3
# Out:
# '%.3f'

# %% [markdown]
# ### 7.2 데이터 시각화 기초

# %% [markdown]
# 7.2.1 막대 그래프
# 범주별(지역별, 부문별 등)로 수치를 비교할 때 적절
# - pyplot 모듈의 bar 함수 이용
# - xtick : 막대에 레이블 표시
# - 그래프 디폴트 : 왼쪽 정렬

# %%
# 대상 데이터
x = [1, 2, 3]
y = [10, 1, 4]

# 그래프 크기 지정
plt.figure(figsize = (10, 6))

plt.bar(x, y, align = 'center', width = 0.5)

# 막대 그래프의 각 레이블
plt.xticks(x, ['A Class', 'B Class', 'C Class'])

# x와 y 레이블 설정
plt.xlabel('Class')
plt.ylabel('Score')

# 그리드 표시
plt.grid(True)

# %% [markdown]
# 가로형 막대 그래프

# %%
# 대상 데이터
x = [1, 2, 3]
y = [10, 1, 4]

# 그래프 크기 지정
plt.figure(figsize = (10, 6))
plt.barh(x, y, align = 'center')
plt.yticks(x, ['A Class', 'B Class', 'C Class'])
plt.ylabel('Class')
plt.xlabel('Score')
plt.grid(True)

# %% [markdown]
# 비교 막대 그래프 그리기

# %%
# 1학기 수학 성적과 최족 성적 비교하기

# 데이터 생성
y1 = np.array([30, 10, 40])
y2 = np.array([10, 50, 90])

# x축 데이터
x = np.arange(len(y1))

print(x)

# 그래프 너비
w = 0.4

# 그래프 크기 지정
plt.figure(figsize = (10, 6))

# 그래프 출력. y2는 막대의 너비만큼 오른쪽으로 이동시켜 그림
plt.bar(x, y1, color = 'blue', width = w, label = 'Math first', align = 'center')
plt.bar(x + w, y2, color = 'green', width = w, label = 'Math final', align = 'center')


# 최적 위치에 범례 배치
plt.legend(loc = 'best')

plt.xticks(x + w / 2, ['Class A', 'Class B', 'Class C'])
plt.grid(True)
# Out:
# [0 1 2]

# %% [markdown]
# 누적 막대 그래프

# %%
# bar 함수를 사용하지만 bottom 파라미터 설정에 주목
# 위로 누적하는 그래프는 bar의 파라미터를 bottom = <아래에 위치하는 데이터>로 지정

# 데이터 생성
height1 = np.array([100, 200, 300, 400, 500])
height2 = np.array([1000, 800, 600, 400, 200])

# x축
x = np.array([1, 2, 3, 4, 5])

# 그래프 크기 지정
plt.figure(figsize = (10, 6))

# 그래프 출력
p1 = plt.bar(x, height1, color = 'blue')
p2 = plt.bar(x, height2, bottom = height1, color = 'lightblue')

# 범례 표시
plt.legend((p1[0], p2[0]), ('Class 1', 'Class 2'))

# %% [markdown]
# 7.2.2 원 그래프

# %% [markdown]
# 일반적인 원 그래프

# %%
# pie 함수 사용, 크기와 레이블 설정
# axis 함수로 그래프를 원형으로 지정
# auto 파라미터로 비율 표시 형식 지정
# explode 파라미터로 특정 범주만 전체 원에서 분리 가능
# startangle 파라미터로 각 요소 출력 시 시작 각도 표시 -> 시작 위치 변경 가능, 90도 지정 시 위쪽 가운데에서 시작, 시계 반대 방향은 양수값 지정, 시계 방향은 음수값 지정
# counterclock 파라미터로 출력 방향 지정, True & default는 시계 방향, False는 시계 반대 방향

labels = ['Frogs', 'Hogs', 'Dogs', 'Logs']
sizes = [15, 30, 45, 10]
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
explode = (0, 0.1, 0, 0)

# 그래프 크기 지정
plt.figure(figsize = (15, 6))

# 그래프 출력
plt.pie(sizes, explode = explode, labels = labels, colors = colors,
        autopct = '%1.1f%%', shadow = True, startangle = 90)

# pie(x, explode=None, labels=None, colors=None, 
#     autopct=None, pctdistance=0.6, shadow=False, labeldistance=1.1, startangle=None, 
#     radius=None, counterclock=True, wedgeprops=None, textprops=None, center=(0, 0), 
#     frame=False, rotatelabels=False, *, data=None)

# 원을 그림
plt.axis('equal')
# Out:
# (-1.214, 1.135, -1.126, 1.101)

# %% [markdown]
# 버블 차트

# %%
# scatter 함수로 버블 차트 그리기

N = 25 

# 무작위로 X, Y 데이터 생성
x = np.random.rand(N)
y = np.random.rand(N)

# color 번호
colors = np.random.rand(N)

# 버블 크기를 다양하게
area = 10 * np.pi * (15 * np.random.rand(N)) ** 2

# 그래프 크기 지정
plt.figure(figsize = (15, 6))

# 그래프 출력
plt.scatter(x, y, s =area, c = colors, alpha = 0.5)
plt.grid(True)

# %% [markdown]
# **Let's try**
# 연습문제 외에도 다른 데이터를 이용해 다양한 그래프를 그려 봅시다.
# 각기 다른 목적에 맞게 어떤 그래프를 그릴 수 있을까요?

# %% [markdown]
# ### [ 연습문제 7 - 1 ]
# 3장의 수학 성적 데이터 student-mat.csv에서 학교를 선택한 이유(reason)를 원 그래프로 그리고 각 비율을 산출해보세요.

# %%
import requests, zipfile
from io import StringIO
import io

# url 지정
url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/00356/student.zip'

# data 받기
r = requests.get(url, stream = True)

# zipfile 읽어들여 압출풀기
z = zipfile.ZipFile(io.BytesIO(r.content))
z.extractall()


student_data_math = pd.read_csv('student-mat.csv', sep = ';')

# %%
reason = student_data_math.groupby('reason').size().plot(kind='pie', autopct = '%1.1f%%', startangle = 90)
plt.ylabel('')
plt.axis('equal')
# Out:
# (-1.119, 1.110, -1.104, 1.100)

# %%
student_data_math.groupby('reason').size().plot(kind='pie', autopct = '%1.1f%%', startangle = 90)

plt.ylabel('')
plt.axis('equal')
# Out:
# (-1.119, 1.110, -1.104, 1.100)

# %%
reason = student_data_math.groupby('reason').size()

labels = ['course', 'home', 'other', 'reputation']
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']

# 그래프 크기 지정
plt.figure(figsize = (15, 6))

# 그래프 출력
plt.pie(reason, labels = labels, colors = colors,
        autopct = '%1.1f%%', startangle = 90)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f16de21ca10>,
# ...
#  [Text(-1.005492204120148, 0.4460778266778197, 'course'),
#   Text(0.03498908253270637, -1.0994433883122494, 'home'),
#   Text(1.0191723530917927, -0.413869199981514, 'other'),
#   Text(0.8155050493734659, 0.7382083137207147, 'reputation')],
#  [Text(-0.5484502931564442, 0.24331517818790163, '36.7%'),
#   Text(0.019084954108748924, -0.5996963936248633, '27.6%'),
#   Text(0.5559121925955233, -0.22574683635355305, '9.1%'),
#   Text(0.44482093602189043, 0.40265908021129887, '26.6%')])

# %% [markdown]
# ### [ 연습문제 7 - 2 ]
# 연습문제 7-1 데이터에서 higher(대학 진학 의향. 값은 yes or no)를 기준으로 응답별 최종 학기 수학 성적 G3 평균을 막대 그래프로 나타내세요.
# 그래프에서 무엇인가 발견할 수 있는 사실이 있나요?

# %%
student_data_math.groupby('higher')['G3'].mean().plot(kind = 'bar')

# 대학 진학 의향이 있는 쪽이 성적 평균이 높다

# %% [markdown]
# ### [ 연습문제 7 - 3 ]
# 같은 데이터에서 통학시간(traveltime)을 기준으로 최종 학기 수학 성적 G3 평균을 가로 막대 그래프로 나타내세요.
# 출력 결과에서 발견할 수 있는 사실이 있나요?

# %%
student_data_math.groupby('traveltime')['G3'].mean().plot(kind = 'barh')

# 통학시간이 짧을수록 성적이 높다? 통학시간이 성적에 영향을 미친다?

# %%
# 대상 데이터
x = ['1', 'B Class', 'C Class']
y = [10, 1, 4]

# 그래프 크기 지정
plt.figure(figsize = (10, 6))

plt.bar(x, y, align = 'center', width = 0.5)

# x와 y 레이블 설정
plt.xlabel('Class')
plt.ylabel('Score')

# 그리드 표시
plt.grid(True)

# %% [markdown]
# ### 7.3 응용 : 금융 데이터 시각화

# %% [markdown]
# 7.3.1 시각화 대상 금융 데이터

# %%
# 날짜 데이터 설정. freq = 'T'로 1분마다 데이터 생성
idx = pd.date_range('2015/01/01', '2015/12/31 23:59', freq = 'T')

# 난수 발생. 1이나 -1을 발생시킴
dn = np.random.randint(2, size = len(idx)) * 2 - 1

# 랜덤워크 (무작위로 수치가 증가 또는 감소하는 데이터) 생성
# cum.prod는 누적곱셈 계산
# (첫 번째 원소 * 두 번째 원소 * 세 번째 원소 * ... * 와 같이 차례대로 원소를 누적해서 곱함)
rnd_walk = np.cumprod(np.exp(dn * 0.0002)) * 100

# resample('B')로 데이터를 영업일 단위로 리샘플링
# ohlc 메서드로 open, high, low, close라는 4개의 데이터로 구분
df = pd.Series(rnd_walk, index = idx).resample('B').ohlc()

# %%
df.plot(figsize = (15, 6), legend = 'best', grid = True)

# %% [markdown]
# 7.3.2 캔들 차트 생성 라이브러리

# %%
# plotly 라이브러리 설치 필요
# plotly의 캔들차트 기능 이용

# plotly 모듈 임포트
from plotly.offline import init_notebook_mode, iplot
from plotly import figure_factory as FF

# 주피터 노트북용 설정
init_notebook_mode(connected = True)

# 캔들 차트 설정
fig = FF.create_candlestick(df.open, df.high, df.low, df.close, dates = df.index)
iplot(fig)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="61c4d881-c865-4084-9620-f1370119fbd9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("61c4d881-c865-4084-9620-f1370119fbd9")) {
#                     Plotly.newPlot(
# ...

# %% [markdown]
# 7.4 응용 : 분석 결과 제시

# %% [markdown]
# 7.4.1 보고서를 만들 때 주의할 점

# %% [markdown]
# ### 7장 종합문제

# %% [markdown]
# ### [ 종합문제 7 - 1 시계열 데이터 분석 ]
# 판다스와 사이파이를 이용해 시계열 데이터를 분석해 봅시다.

# %% [markdown]
# 1. 데이터 입력과 확인 : 아래의 사이트에서 dow_jones_index.zip을 다운로드하고 dow_jones_index.data 데이터를 읽어 들인 후 처음 다섯 행을 출력하세요. 또한 데이터의 각 컬럼 정보를 확인하고 NaN이 있는지 확인하세요.

# %%
url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/00312/dow_jones_index.zip'

# data 받기
dow = requests.get(url, stream = True)

# zipfile 읽어들여 압출풀기
zip_file = zipfile.ZipFile(io.BytesIO(dow.content))
zip_file.extractall()

# 파일 불러오기
dow = pd.read_csv('dow_jones_index.data')

# %%
# 파일의 첫 5행 확인하기
dow.head()
# Out:
#    quarter stock  ... days_to_next_dividend percent_return_next_dividend
# 0        1    AA  ...                    26                     0.182704
# 1        1    AA  ...                    19                     0.187852
# 2        1    AA  ...                    12                     0.189994
# 3        1    AA  ...                     5                     0.185989
# 4        1    AA  ...                    97                     0.175029
#
# [5 rows x 16 columns]

# %%
# 데이터의 컬럼 정보 확인
dow.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 750 entries, 0 to 749
# Data columns (total 16 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   quarter                             750 non-null    int64
#  1   stock                               750 non-null    object
#  2   date                                750 non-null    object
#  3   open                                750 non-null    object
#  4   high                                750 non-null    object
#  5   low                                 750 non-null    object
#  6   close                               750 non-null    object
#  7   volume                              750 non-null    int64
#  8   percent_change_price                750 non-null    float64
#  9   percent_change_volume_over_last_wk  720 non-null    float64
#  10  previous_weeks_volume               720 non-null    float64
# ...

# %%
# NaN 확인
dow_nan = dow.isnull().any().any()
print(dow_nan)
# Out:
# True

# %% [markdown]
# 2. 데이터 가공 : opewn, high, low, close 등의 컬럼 데이터에는 숫자 앞에 $ 기호가 붙어 있습니다. 이 기호를 제거하세요. 또한 날짜와 시간을 date 형으로 읽어들이지 않은 경우 date형으로 바꾸세요.

# %%
# 형변환 날짜형
dow.date = pd.to_datetime(dow.date)

# %%
# $ 기호 제거
delete_dolchar = lambda x : str(x).replace('$', '')

dow.open = pd.to_numeric(dow.open.map(delete_dolchar))
dow.high = pd.to_numeric(dow.high.map(delete_dolchar))
dow.low = pd.to_numeric(dow.low.map(delete_dolchar))
dow.close = pd.to_numeric(dow.close.map(delete_dolchar))

# %% [markdown]
# 3. close 컬럼에서 각 stock별로 요약통계량을 산출하세요.

# %%
# dow.groupby('close')['stock'].summary

dow_jones_index_stock_index = dow.set_index(['date', 'stock'])

dow_jones_index_stock_index_unstack = dow_jones_index_stock_index.unstack()

dow_close_data = dow_jones_index_stock_index_unstack['close']

dow_close_data.describe()
# Out:
# stock         AA        AXP         BA  ...        VZ        WMT        XOM
# count  25.000000  25.000000  25.000000  ...  25.00000  25.000000  25.000000
# mean   16.504400  46.712400  73.448000  ...  36.46960  53.912800  82.111600
# std     0.772922   2.396248   3.087631  ...   0.93282   1.555639   3.137743
# min    14.720000  43.530000  69.100000  ...  34.95000  51.520000  75.590000
# 25%    16.030000  44.360000  71.640000  ...  35.84000  52.540000  79.780000
# 50%    16.520000  46.250000  72.690000  ...  36.31000  53.660000  82.630000
# 75%    17.100000  48.500000  74.840000  ...  37.26000  55.290000  84.500000
# max    17.920000  51.190000  79.780000  ...  38.47000  56.700000  87.980000
#
# [8 rows x 30 columns]

# %% [markdown]
# 4. close 컬럼에서 각 stock의 상관행렬을 계산하고 씨본의 heatmap 함수를 이용해 상관행렬 히트맵을 그리세요. (히트 : 판다스의 corr 메서드를 이용합니다.)

# %%
corr_data = dow_close_data.corr()
corr_data
# Out:
# stock        AA       AXP        BA  ...        VZ       WMT       XOM
# stock                                ...
# AA     1.000000 -0.132094  0.291520  ...  0.728472  0.171045  0.685739
# AXP   -0.132094  1.000000  0.792575  ...  0.239228  0.261840 -0.036042
# BA     0.291520  0.792575  1.000000  ...  0.566156  0.224755  0.444624
# BAC    0.432240 -0.746595 -0.536545  ... -0.089458  0.131447  0.123588
# CAT    0.695727  0.255515  0.627205  ...  0.890315 -0.170677  0.803195
# CSCO   0.277191 -0.593743 -0.465162  ... -0.228347  0.501898 -0.120732
# CVX    0.470529  0.236456  0.568946  ...  0.764618 -0.436621  0.802900
# DD     0.762246  0.004094  0.417249  ...  0.796600 -0.144215  0.863511
# DIS    0.772470 -0.129064  0.350917  ...  0.594160 -0.062269  0.803492
# GE     0.740139 -0.315425  0.139263  ...  0.411936  0.268604  0.720823
# HD     0.744726 -0.201676  0.208978  ...  0.632286  0.167338  0.716404
# HPQ    0.463457 -0.627805 -0.424803  ... -0.095685  0.436606  0.075982
# ...

# %%
sns.heatmap(corr_data)

# %% [markdown]
# 5. 4번에서 계산한 상관행렬 중에서 상관계수가 가장 높은 stock 조합을 추출하세요. 또한 그중 가장 상관계수가 높은 쌍을 추출하고 시계열 그래프를 그리세요.

# %%
max_corr = 0
stock_1 = ''
stock_2 = ''

for i in range(0, len(corr_data)):
  print(
      corr_data[i:i+1].unstack().sort_values(ascending = False)
  )
# Out:
# stock  stock
# AA     AA       1.000000
# DIS    AA       0.772470
# DD     AA       0.762246
# HD     AA       0.744726
# GE     AA       0.740139
# JPM    AA       0.736155
# VZ     AA       0.728472
# CAT    AA       0.695727
# XOM    AA       0.685739
# CVX    AA       0.470529
# HPQ    AA       0.463457
# BAC    AA       0.432240
# MMM    AA       0.408274
# UTX    AA       0.407474
# TRV    AA       0.405575
# MSFT   AA       0.317951
# BA     AA       0.291520
# CSCO   AA       0.277191
# KO     AA       0.277167
# IBM    AA       0.268968
# WMT    AA       0.171045
# PFE    AA       0.111613
# INTC   AA       0.085051
# T      AA       0.030825
# AXP    AA      -0.132094
# PG     AA      -0.162919
# MRK    AA      -0.194258
# KRFT   AA      -0.322700
# MCD    AA      -0.368521
# JNJ    AA      -0.393426
# dtype: float64
# stock  stock
# AXP    AXP      1.000000
# KRFT   AXP      0.873510
# MCD    AXP      0.859645
# JNJ    AXP      0.854853
# T      AXP      0.853905
# ...

# %% [markdown]
# 6. 판다스 rolling 메서드를 이용해 stock별로 close이 과거 5기(5주간) 이동평균 시계열 데이터를 생성하세요.

# %%
dow_close_data.rolling(center=False, window=5).mean()
# Out:
# stock           AA     AXP      BA     BAC  ...     UTX      VZ     WMT     XOM
# date                                        ...
# 2011-01-07     NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN
# 2011-01-14     NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN
# 2011-01-21     NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN
# 2011-01-28     NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN
# 2011-02-04  16.290  44.858  70.348  14.328  ...  80.462  35.656  55.470  78.936
# 2011-02-11  16.480  45.336  70.900  14.432  ...  81.686  35.748  55.792  80.382
# 2011-02-18  16.742  45.192  71.494  14.332  ...  82.872  35.980  55.906  81.714
# 2011-02-25  16.920  44.698  71.618  14.322  ...  83.506  36.184  55.110  82.986
# 2011-03-04  17.010  44.670  72.132  14.426  ...  83.792  36.274  54.184  84.204
# 2011-03-11  16.788  44.762  72.184  14.444  ...  83.544  36.182  53.496  83.972
# ...

# %% [markdown]
# 7. 판다스 shift 메서드를 사용해 stock별로 close의 전 기간(1주전) 대비 비율을 로그시계열 데이터로 계산하세요. 그중 가장 표준편차가 큰 stock과 작은 stock을 추출해 로그 변화비율 그래프를 그리세요.

# %% [markdown]
# ### [ 종합문제 7 - 2 마케팅 분석]

# %% [markdown]
# 1. 아래 url에서 데이터를 판다스로 읽어 들입니다. (50만 건 이상의 비교적 큰 데이터이므로 시간이 조금 걸립니다.)
#
# customer ID 데이터가 있는 행 데이터만 분석 대상이므로 해당되는 데이터만 추출하세요. InvoiceNo 컬럼 데이터에서 숫자 앞에 붙은 C는 구매 취소를 의미하므로 값이 C인 행의 데이터도 제거하세요. 그 밖에 불필요한 데이터도 적절하게 제거하고 정리된 데이터를 대상으로 분석하세요.

# %%
file_url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/00352/Online%20Retail.xlsx'
online_retail_data = pd.ExcelFile(file_url)

# %%
online_retail_data_table = online_retail_data.parse('Online Retail')
online_retail_data_table.head()
# Out:
#   InvoiceNo StockCode  ... CustomerID         Country
# 0    536365    85123A  ...    17850.0  United Kingdom
# 1    536365     71053  ...    17850.0  United Kingdom
# 2    536365    84406B  ...    17850.0  United Kingdom
# 3    536365    84029G  ...    17850.0  United Kingdom
# 4    536365    84029E  ...    17850.0  United Kingdom
#
# [5 rows x 8 columns]

# %%
online_retail_data_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %% [markdown]
# 2. 데이터에는 구매 날짜와 상품명, 수량, 횟수, 구매자 ID 등의 컬럼이 있습니다. 고유한 구매자 수(CustomerID) ,장바구니 수(고유한 InvoiceNo번호), 상품 종류(StockCode 기반과 Description 기반 고유 번호) 수를 구하세요.

# %%
size(online_retail_data_table.CustomerID.unique())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-7f703a9fda34> in <module>()
# ----> 1 size(online_retail_data_table.CustomerID.unique())
#
# NameError: name 'size' is not defined

# %% [markdown]
# 3. 데이터에 Country 컬럼이 있습니다. 이 컬럼을 기준으로 각 나라별 구매 금액 합계(단위당 금액 * 수량 합계)를 구하고, 내림차순으로 정렬한 후 상위 다섯 개 국가를 출력하세요.

# %% [markdown]
# 4. 3에서 구한 상위 다섯 개 국가에서 국가별 매출(총액)의 월별 시계열 추이를 그래프로 나타내세요.

# %% [markdown]
# 5. 3에서 추출한 상위 다섯 개 국가에서 국가별 매출 상위 5개 제품을 추출하고 원 그래프를 그리세요. 제품은 Description 기준으로 집계합니다.

# %%
class Rect:
    # 인스턴스가 생성될 때 호출되는 특수한 메서드를 정의합니다.
    def __init__(self, width, height):
        self.width = width    # width 속성에 값을 할당합니다.
        self.height = height  # height 속성에 값을 할당합니다.
    # 사각형의 넓이를 계산하는 메서드를 정의합니다.
    def area(self):
        return self.width * self.height

# %%
r = Rect(100, 20)
print(r.width, r.height, r.area())   # 100 20 2000을 출력합니다.

# %%
# Rect를 상속받아 Square 클래스를 정의합니다.
class Square(Rect):
    def __init__(self, width):
        # 부모 클래스의 메서드를 호출합니다.
        super().__init__(width, width)

# %%
s = Square(20)
print(s.area())
